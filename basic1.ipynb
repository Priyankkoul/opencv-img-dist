# %%
import cv2
import numpy as np
import scipy
from scipy.spatial import distance
#from scipy.misc import imread
import _pickle as cPickle
#import cPickle as pickle
import pickle
import random
import os
import matplotlib.pyplot as plt
import skimage, imageio
from pathlib import Path

# %%
# Feature extractor
def extract_features(image_path):
    #image = imageio.imread(image_path)
        # Using KAZE, cause SIFT, ORB and other was moved to additional module
        # which is adding addtional pain during install
        #print(image_path)
    try:
        image = cv2.imread(image_path) 
        sift = cv2.xfeatures2d.SIFT_create()
            # Dinding image keypoints
        keypoints, dsc_1= sift.detectAndCompute(image,None)
            # Getting first 32 of them. 
            # Number of keypoints is varies depend on image size and color pallet
            # Sorting them based on keypoint response value(bigger is better)
            #kps = sorted(kps, key=lambda x: -x.response)[:vector_size]
            # computing descriptors vector
            #kps, dsc = alg.compute(image, kps)
            # Flatten all of them in one big vector - our feature vector
        dsc_1=dsc_1.flatten()
        dsc_1 = np.concatenate([dsc_1, np.zeros(2560 - len(dsc_1))])

        return dsc_1
    except:
        return []

from numpy import save,load
def batch_extractor():
    discarded=[]
    for _ in range(0,10):
        result={}
        
        for i in glob.glob("trainingSet/trainingSet/"+str(_)+ "/*.jpg"):
            result[i]=extract_features(i)
        #print(len(result.keys()))
        for j in result.keys():
            if(len(result[j])>0):
                
                save('dsc_data/'+str(_)+'/'+str(j)[26:]+'.npy', result[j])
            else:
                discarded.append(j)
    with open("discared.txt",'w') as f:
            for op in discarded:
                f.write(op+'\n')

# %%
from scipy.spatial.distance import cdist 

def dist(v1,v2):
    return 1-cdist(v1.reshape(1,-1),v2.reshape(1,-1),"cosine")[0][0]

# %%
import random as rd
def run():
    for numbers in range(0,10):
        print("DOING FOR NUMBER",numbers)
        files=[ i for i in glob.glob("trainingSet/trainingSet/"+str(numbers)+"/*.jpg")]           #for to be used
        #print(len(files))
        sample = rd.sample(files,2)

        print("3 RANDOM FILES:\n",sample)




        #batch_extractor()





        #0
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/0/*.jpg"):

                try:
                    v2= load('dsc_data/0/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("0 -->  ",c)




        #1
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/1/*.jpg"):

                try:
                    v2= load('dsc_data/1/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("1 -->  ",c)



        #2
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/2/*.jpg"):

                try:
                    v2= load('dsc_data/2/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("2 -->  ",c)


        #3
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/3/*.jpg"):

                try:
                    v2= load('dsc_data/3/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("3 -->  ",c)



        #4
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/4/*.jpg"):

                try:
                    v2= load('dsc_data/4/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("4 -->  ",c)

        #5
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/5/*.jpg"):

                try:
                    v2= load('dsc_data/5/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("5 -->  ",c)



        #6
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/6/*.jpg"):

                try:
                    v2= load('dsc_data/6/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("6 -->  ",c)


        #7
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/7/*.jpg"):

                try:
                    v2= load('dsc_data/7/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("7 -->  ",c)



        #8
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/8/*.jpg"):

                try:
                    v2= load('dsc_data/8/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("8 -->  ",c)

        #9
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/9/*.jpg"):

                try:
                    v2= load('dsc_data/9/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("9 -->  ",c)


        
        
run()
# Out:
# DOING FOR NUMBER 0
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/0/img_25021.jpg', 'trainingSet/trainingSet/0/img_23635.jpg']
# 0 -->   49
# 1 -->   143
# 2 -->   8
# 3 -->   11
# 4 -->   22
# 5 -->   21
# 6 -->   85
# 7 -->   20
# 8 -->   20
# 9 -->   121
# DOING FOR NUMBER 1
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/1/img_24579.jpg', 'trainingSet/trainingSet/1/img_6000.jpg']
# 0 -->   44
# 1 -->   1468
# 2 -->   53
# 3 -->   26
# 4 -->   137
# 5 -->   61
# 6 -->   209
# 7 -->   336
# 8 -->   90
# 9 -->   245
# DOING FOR NUMBER 2
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/2/img_23614.jpg', 'trainingSet/trainingSet/2/img_15900.jpg']
# 0 -->   0
# 1 -->   1
# 2 -->   8
# 3 -->   7
# 4 -->   10
# 5 -->   1
# 6 -->   2
# 7 -->   3
# 8 -->   1
# 9 -->   4
# DOING FOR NUMBER 3
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/3/img_21122.jpg', 'trainingSet/trainingSet/3/img_40507.jpg']
# 0 -->   2
# 1 -->   0
# 2 -->   0
# 3 -->   6
# 4 -->   0
# 5 -->   0
# 6 -->   0
# 7 -->   1
# 8 -->   0
# 9 -->   1
# DOING FOR NUMBER 4
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/4/img_29082.jpg', 'trainingSet/trainingSet/4/img_19737.jpg']
# 0 -->   0
# 1 -->   0
# 2 -->   12
# 3 -->   0
# 4 -->   34
# 5 -->   6
# 6 -->   0
# 7 -->   4
# 8 -->   4
# 9 -->   5
# DOING FOR NUMBER 5
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/5/img_35823.jpg', 'trainingSet/trainingSet/5/img_23525.jpg']
# 0 -->   15
# 1 -->   64
# 2 -->   13
# 3 -->   13
# 4 -->   6
# 5 -->   20
# 6 -->   20
# 7 -->   74
# 8 -->   10
# 9 -->   12
# DOING FOR NUMBER 6
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/6/img_34888.jpg', 'trainingSet/trainingSet/6/img_33463.jpg']
# 0 -->   49
# 1 -->   3
# 2 -->   17
# 3 -->   12
# 4 -->   42
# 5 -->   30
# 6 -->   165
# 7 -->   33
# 8 -->   43
# 9 -->   90
# DOING FOR NUMBER 7
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/7/img_40967.jpg', 'trainingSet/trainingSet/7/img_17506.jpg']
# 0 -->   22
# 1 -->   304
# 2 -->   148
# 3 -->   105
# 4 -->   79
# 5 -->   49
# 6 -->   70
# 7 -->   547
# 8 -->   58
# 9 -->   148
# DOING FOR NUMBER 8
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/8/img_27981.jpg', 'trainingSet/trainingSet/8/img_38397.jpg']
# 0 -->   50
# 1 -->   431
# 2 -->   50
# 3 -->   25
# 4 -->   123
# 5 -->   46
# 6 -->   121
# 7 -->   46
# 8 -->   103
# 9 -->   203
# DOING FOR NUMBER 9
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/9/img_12287.jpg', 'trainingSet/trainingSet/9/img_39453.jpg']
# 0 -->   22
# 1 -->   123
# 2 -->   16
# 3 -->   11
# 4 -->   29
# 5 -->   24
# 6 -->   33
# 7 -->   27
# 8 -->   21
# 9 -->   44
