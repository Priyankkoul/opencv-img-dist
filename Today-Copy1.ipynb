# %%
import cv2
import numpy as np
import scipy
from scipy.spatial import distance
#from scipy.misc import imread
import _pickle as cPickle
#import cPickle as pickle
import pickle
import random
import os
import matplotlib.pyplot as plt
import skimage, imageio
from pathlib import Path
import glob
# Out:
# In /home/priyank/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The text.latex.preview rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/priyank/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The mathtext.fallback_to_cm rcparam was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# In /home/priyank/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle: Support for setting the 'mathtext.fallback_to_cm' rcParam is deprecated since 3.3 and will be removed two minor releases later; use 'mathtext.fallback : 'cm' instead.
# In /home/priyank/.local/lib/python3.6/site-packages/matplotlib/mpl-data/stylelib/_classic_test.mplstyle:
# The validate_bool_maybe_none function was deprecated in Matplotlib 3.3 and will be removed two minor releases later.
# ...

# %%
# Feature extractor
def extract_features(image_path):
    #image = imageio.imread(image_path)
        # Using KAZE, cause SIFT, ORB and other was moved to additional module
        # which is adding addtional pain during install
        #print(image_path)
    try:
        image = cv2.imread(image_path) 
        sift = cv2.xfeatures2d.SIFT_create()
            # Dinding image keypoints
        keypoints, dsc_1= sift.detectAndCompute(image,None)
            # Getting first 32 of them. 
            # Number of keypoints is varies depend on image size and color pallet
            # Sorting them based on keypoint response value(bigger is better)
            #kps = sorted(kps, key=lambda x: -x.response)[:vector_size]
            # computing descriptors vector
            #kps, dsc = alg.compute(image, kps)
            # Flatten all of them in one big vector - our feature vector
        dsc_1=dsc_1.flatten()
        dsc_1 = np.concatenate([dsc_1, np.zeros(2560 - len(dsc_1))])

        return dsc_1
    except:
        return []

from numpy import save,load
def batch_extractor(file_path):
    if not os.path.exists(file_path+'/dsc_data'):
        os.makedirs(file_path+'/dsc_data')
    for x in range(10):
        current_directory = file_path+'/dsc_data'
        final_directory = os.path.join(current_directory, r''+str(x))
        if not os.path.exists(final_directory):
           os.makedirs(final_directory)
    discarded=[]
    for _ in range(0,10):
        result={}
        
        for i in glob.glob("trainingSet/trainingSet/"+str(_)+ "/*.jpg"):
            result[i]=extract_features(i)
        #print(len(result.keys()))
        for j in result.keys():
            if(len(result[j])>0):
                
                save('dsc_data/'+str(_)+'/'+str(j)[26:]+'.npy', result[j])
            else:
                discarded.append(j)
    with open("discared.txt",'w') as f:
            for op in discarded:
                f.write(op+'\n')

# %%
from scipy.spatial.distance import cdist 

def dist(v1,v2):
    return 1-cdist(v1.reshape(1,-1),v2.reshape(1,-1),"cosine")[0][0]

# %%
file_path="/home/priyank/final_shell1/final_shell1"
import random as rd
def run():
    for numbers in range(0,10):
        print("DOING FOR NUMBER",numbers)
        files=[ i for i in glob.glob("trainingSet/trainingSet/"+str(numbers)+"/*.jpg")]           #for to be used
        #print(len(files))
        sample = rd.sample(files,2)

        print("3 RANDOM FILES:\n",sample)




        #batch_extractor(file_path)





        #0
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/0/*.jpg"):

                try:
                    v2= load('dsc_data/0/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("0 -->  ",c)




        #1
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/1/*.jpg"):

                try:
                    v2= load('dsc_data/1/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("1 -->  ",c)



        #2
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/2/*.jpg"):

                try:
                    v2= load('dsc_data/2/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("2 -->  ",c)


        #3
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/3/*.jpg"):

                try:
                    v2= load('dsc_data/3/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("3 -->  ",c)



        #4
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/4/*.jpg"):

                try:
                    v2= load('dsc_data/4/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("4 -->  ",c)

        #5
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/5/*.jpg"):

                try:
                    v2= load('dsc_data/5/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("5 -->  ",c)



        #6
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/6/*.jpg"):

                try:
                    v2= load('dsc_data/6/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("6 -->  ",c)


        #7
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/7/*.jpg"):

                try:
                    v2= load('dsc_data/7/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("7 -->  ",c)



        #8
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                    #for to be used
            for images in glob.glob("trainingSet/trainingSet/8/*.jpg"):

                try:
                    v2= load('dsc_data/8/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("8 -->  ",c)

        #9
        c=0
        for i in sample:
            data = load('dsc_data/'+str(numbers)+ '/'+i[26:]+'.npy')                   #for to be used
            for images in glob.glob("trainingSet/trainingSet/9/*.jpg"):

                try:
                    v2= load('dsc_data/9/'+ images[26:]+'.npy')
                    temp=dist(data,v2)
                    if(temp>=0.6 and temp<0.8):
                        c+=1


                except:
                    pass
        print("9 -->  ",c)


        
        
run()
# Out:
# DOING FOR NUMBER 0
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/0/img_18026.jpg', 'trainingSet/trainingSet/0/img_11030.jpg']
# 0 -->   46
# 1 -->   191
# 2 -->   25
# 3 -->   23
# 4 -->   27
# 5 -->   25
# 6 -->   118
# 7 -->   106
# 8 -->   17
# 9 -->   72
# DOING FOR NUMBER 1
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/1/img_28155.jpg', 'trainingSet/trainingSet/1/img_3527.jpg']
# 0 -->   55
# 1 -->   1527
# 2 -->   59
# 3 -->   16
# 4 -->   70
# 5 -->   35
# 6 -->   135
# 7 -->   223
# 8 -->   56
# 9 -->   117
# DOING FOR NUMBER 2
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/2/img_19938.jpg', 'trainingSet/trainingSet/2/img_12459.jpg']
# 0 -->   3
# 1 -->   1
# 2 -->   33
# 3 -->   18
# 4 -->   8
# 5 -->   15
# 6 -->   3
# 7 -->   21
# 8 -->   7
# 9 -->   4
# DOING FOR NUMBER 3
# 3 RANDOM FILES:
#  ['trainingSet/trainingSet/3/img_41481.jpg', 'trainingSet/trainingSet/3/img_20044.jpg']
# 0 -->   3
# 1 -->   4
# 2 -->   11
# 3 -->   31
# 4 -->   87
# 5 -->   22
# 6 -->   44
# ...
